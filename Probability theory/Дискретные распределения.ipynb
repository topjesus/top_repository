# %% [markdown]
# # Дискретные Распределения
#
# Условные обозначения:
#
# $\Omega$ - пространство элементарных событий $(P(\Omega) = 1)$
#
# $A \subseteq \Omega$ - случайное событие. Также обозначается как $A,B,C,...,A_1,A_2,...$
#
# $$

# %% [markdown]
# ## 1. Биномиальное распределение
#
# Пусть:
#
# $A$ - исследуемое событие
#
# $p$ - вероятность появление события $A$
#
# $n$ - количество всех испытаний
#
# $m$ - количество появления события $A$ $(m \leq n)$
#
# $P_n(m) = C_n^m \cdot p^m \cdot (1-p)^{n-m}$

# %%
import matplotlib.pyplot as plt
plt.plot([3,4])
